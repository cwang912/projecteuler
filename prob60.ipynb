# %% [markdown]
# # Problem 60

# %% [markdown]
# The primes 3, 7, 109, and 673, are quite remarkable. By taking any two primes and concatenating them in any order the result will always be prime. For example, taking 7 and 109, both 7109 and 1097 are prime. The sum of these four primes, 792, represents the lowest sum for a set of four primes with this property.
#
# Find the lowest sum for a set of five primes for which any two primes concatenate to produce another prime.

# %%
def primes_sieve(limit):
    a = [True] * limit                        # initialize the primality list
    a[0] = a[1] = False
    for (i, isprime) in enumerate(a):
        if isprime:
            yield i
            for n in xrange(i*i, limit, i):     # mark factors non-prime
                a[n] = False

def is_prime(n):
    if n == 1 or n%2 == 0:
        return False
    for i in xrange(3,int((abs(n)**0.5))+1,2):
        if n%i == 0:
            return False
    return True

def compatible(i,j):
    for n in i:
        if not is_prime(int(str(n)+str(j))) or not is_prime(int(str(j)+str(n))):
            return False
    return True
    
limit = 10000

sieve = dict.fromkeys(primes_sieve(limit))
sieve_list = list(primes_sieve(limit))

# %%
for n1,x1 in enumerate(sieve_list):
    for n2,x2 in enumerate(sieve_list[n1+1:]):
        if compatible([x1],x2):
            for n3,x3 in enumerate(sieve_list[n2+1:]):
                if compatible([x1,x2],x3):
                    for n4,x4 in enumerate(sieve_list[n3+1:]):
                        if compatible([x1,x2,x3],x4):
                            for n5,x5 in enumerate(sieve_list[n4+1:]):
                                if compatible([x1,x2,x3,x4],x5):
                                    print sum([x1,x2,x3,x4,x5]),[x1,x2,x3,x4,x5]
# Out:
# 26033 [13, 5197, 5701, 6733, 8389]
# [5, 685, 64, 802, 247]
# 26033 [13, 5197, 6733, 5701, 8389]
# [5, 685, 181, 568, 481]
# 26033
#  [13, 5197, 8389, 5701, 6733]
# [5, 685, 364, 385, 481]
# 26033 [13, 5197, 8389, 6733, 5701]
# [5, 685, 364, 502, 247]
# 26033
#  [13, 5701, 6733, 5197, 8389]
# [5, 744, 122, 568, 481]
# 26033 [13, 5701, 8389, 5197, 6733]
# [5, 744, 305, 385, 481]
# 26033
#  [13, 5701, 8389, 6733, 5197]
# [5, 744, 305, 561, 129]
# 26033
#  [13, 6733, 8389, 5197, 5701]
# [5, 861, 188, 502, 247]
# 26033 [13, 6733, 8389, 5701, 5197]
# [5, 861, 188, 561, 129]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-334-7567adac532e> in <module>()
#       5                 if compatible([x1,x2],x3):
#       6                     for n4,x4 in enumerate(sieve_list[n3+1:]):
# ----> 7                         if compatible([x1,x2,x3],x4):
# ...

# %%
min1,min2,min3,min4,min5 = 50000,50000,50000,50000,50000
total = 50000*5

for n1 in sieve_list:
    for n2 in new[n1]:
        set1 = new[n1].intersection(new[n2])
        for n3 in set1:
            set2 = set1.intersection(new[n3])
            for n4 in set2:
                set3 = set2.intersection(new[n4])
                for n5 in set3:
                    if sum([n1,n2,n3,n4,n5]) < total:
                        min1,min2,min3,min4,min5 = n1,n2,n3,n4,n5
                        total = sum([n1,n2,n3,n4,n5])
    if n1 > 50:
        break

print min1,min2,min3,min4,min5
print total
# Out:
# 7 18433 set([433, 229, 109])
# 7 3 set([10627, 38791, 22921, 41227, 24847, 5521, 14851, 21397, 541, 673, 20899, 19237, 41641, 9901, 27823, 823, 34057, 4159, 29761, 24517, 2503, 15313, 1237, 48889, 10459, 29587, 229, 25189, 29059, 109, 19183, 2707, 4729, 29947])
# 7 30727 set([])
# 7 12301 set([])
# 7 26641 set([757, 127])
# 7 6163 set([5689, 8167, 9349, 2503])
# 7 26647 set([541])
# 7 18457 set([547])
# 7 16411 set([127])
# 7 30757 set([547, 541])
# 7 2089 set([2953, 523, 4219, 2341, 3181])
# 7 36871 set([937, 19])
# 7 28723 set([691])
# 7 24631 set([829])
# 7 47161 set([])
# 7 61 set([29059, 26893, 3181, 15643, 1693, 28069, 1453, 5821, 30781, 13309, 1999, 25939, 33871, 2341, 11617, 8941, 15973, 487, 31981, 34159, 31219, 8311, 41341])
# 7 4159 set([937, 3, 3823, 541, 1471])
# 7 26701 set([487])
# 7 4177 set([8311, 3583, 8101, 4903])
# 7 97 set([3331, 17989, 38083, 883, 13309, 10627, 3727, 10513, 19, 45013, 35311, 28729, 9337, 28027, 4507, 829])
# 7 4201 set([6421, 3823])
# ...
